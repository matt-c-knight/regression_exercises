# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from matplotlib.pyplot import figure
import seaborn as sns


url = 'https://gist.githubusercontent.com/zgulde/018f5d601efc79cb741a7aba92f51d29/raw/c08f1c09f605b43e9a354890f9dd68f296e76dc4/students.csv'
df = pd.read_csv(url)

# %%
df.head()
# Out:
#    ml_coffee  syntax_errors  p_days_absent
# 0      16225   5.071306e+10       0.038821
# 1      18230   5.199823e+10       0.022748
# 2      15877   5.072630e+10       0.036627
# 3       8263   4.907919e+10       0.041293
# 4      13935   5.145114e+10       0.081544

# %% [markdown]
# Create a scatter plot of syntax_errors and ml_coffee. Make sure to give your visual an appropriate title and labels.

# %%
figure(figsize=(12,8))
plt.scatter(x='syntax_errors', y='ml_coffee', data=df)
plt.title('Codeup Students Relationship between Syntax Erros and Consumption of Coffee')
plt.xlabel('Syntax Errors')
plt.ylabel('ML Coffee')
# Out:
# Text(0, 0.5, 'ML Coffee')

# %% [markdown]
# Create a scatter plot of p_days_absent and ml_coffee. Make sure to give your visual an appropriate title and labels.

# %%
figure(figsize=(12,8))
plt.scatter(x='p_days_absent', y='ml_coffee', data=df)
plt.title('Codeup Students Relationship between Syntax Erros and Consumption of Coffee')
plt.xlabel('Syntax Errors')
plt.ylabel('ML Coffee')
# Out:
# Text(0, 0.5, 'ML Coffee')

# %% [markdown]
# Perform any other customizations you think will help to the plots you have created

# %%
figure(figsize=(12,8))
sns.regplot(x='syntax_errors', y='ml_coffee', data=df)

# %%
x = df.syntax_errors
y = df.ml_coffee
from scipy import stats
def r2(x, y):
    return stats.pearsonr(x, y)[0] ** 2
sns.jointplot(x, y, kind="reg", stat_func=r2)
# Out:
# /usr/local/anaconda3/lib/python3.7/site-packages/seaborn/axisgrid.py:1848: UserWarning: JointGrid annotation is deprecated and will be removed in a future release.
#   warnings.warn(UserWarning(msg))

# %%
x = df.syntax_errors
y = df.ml_coffee
from scipy import stats
def r2(x, y):
    return stats.pearsonr(x, y)[0] ** 2
sns.jointplot(x, y, kind="reg", stat_func=r2)
